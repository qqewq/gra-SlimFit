# %% [markdown]
# # SlimFit GRA Experiment
# Optimizing a weight loss plan that minimizes hunger using GRA nullification (static, cyclic, chaotic).

# %%
import sys
sys.path.append('..')
from gra_slimfit.optimizer import optimize
from gra_slimfit.utils import plot_results
import numpy as np

# %%
# Quick optimization with few generations for demo
best_cal, best_prot, best_fib, fitness, _ = optimize(
    initial_weight=80, target_weight=72, duration_days=90,
    pop_size=20, ngen=20
)
print(f"Fitness: {fitness:.4f}")

# %%
plot_results(best_cal, best_prot, best_fib, initial_weight=80)
